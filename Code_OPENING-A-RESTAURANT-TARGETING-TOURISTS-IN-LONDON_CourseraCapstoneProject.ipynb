# %% [markdown]
# <h1>OPENING A RESTAURANT TARGETING TOURISTS IN LONDON - Code - Coursera Capstone Project</h1>

# %%
#importing the needed libraries

import numpy as np

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json

import requests
from pandas.io.json import json_normalize

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if needed
import folium

# %% [markdown]
# <h2>Getting the hotels data and performing needed analysis</h2>

# %% [markdown]
# In this part, we will call the Foursquare API and search for hotels around London city center. Then we will cluster the resulting venues using K-Means clustering to find areas were groups of hotels are located. Finally, we will find the centers of these areas and organize them in a data frame for later analysis.

# %%
#setting the needed information to call Foursquare API

CLIENT_ID = 'HU5FWCR5TTHNPOTBIX5DN4AA5OGWV2RXJCUAEXEA5URYXYQF' # your Foursquare ID
CLIENT_SECRET = '5FSAEAC5ZZOR4VJTYUKEWIHOIYBZ1LHMF05CIOGOT23VIJRD' # your Foursquare Secret
VERSION = '20181216' # Foursquare API version

# %%
#setting the location to be searched, search word, and limits on results

london_lat = 51.5074
london_lon = -0.1278
search_query = 'Hotel'
radius = 500
limit_hotels = 50

# %%
#url to be used forr calling the API

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, london_lat, london_lon, VERSION, search_query, radius, limit_hotels)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=HU5FWCR5TTHNPOTBIX5DN4AA5OGWV2RXJCUAEXEA5URYXYQF&client_secret=5FSAEAC5ZZOR4VJTYUKEWIHOIYBZ1LHMF05CIOGOT23VIJRD&ll=51.5074,-0.1278&v=20181216&query=Hotel&radius=500&limit=50'

# %%
#making the call and holding saving the resulting json file

results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
hotels = results['response']['venues']

# tranform venues into a dataframe
hotels_df = json_normalize(hotels)
hotels_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id  \
# 0  4d274945d86aa09024d41dc0
# 1  5d53299e9293ba0007f03f86
# 2  4bc54daa6a3e9c7496c8f548
# 3  4ac518b5f964a5209fa020e3
# 4  4ad7ed82f964a520241021e3
#
#                                                 name  \
# 0                                    Corinthia Hotel
# 1  Great Scotland Yard Hotel - In the Unbound Col...
# 2                                Club Quarters Hotel
# 3             Radisson Blu Edwardian Hampshire Hotel
# 4                                     W London Hotel
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1622661964    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1622661964    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1622661964    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1622661964    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1622661964    False
#
#                       location.address  location.lat  location.lng  \
# 0                         Whitehall Pl     51.506607     -0.124460
# 1              3-5 Great Scotland Yard     51.506425     -0.126146
# 2              8 Northumberland Avenue     51.506985     -0.126020
# 3               31-36 Leicester Square     51.509867     -0.129767
# 4  Leicester Square, 10 Wardour Street     51.510821     -0.131352
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 51.50660672347560...                247
# 1  [{'label': 'display', 'lat': 51.5064253, 'lng'...                157
# 2  [{'label': 'display', 'lat': 51.50698547522388...                131
# 3  [{'label': 'display', 'lat': 51.5098669, 'lng'...                306
# 4  [{'label': 'display', 'lat': 51.510821, 'lng':...                453
#
#   location.postalCode location.cc   location.city  location.state  \
# 0            SW1A 2BD          GB          London  Greater London
# 1            SW1A 2HN          GB          London             NaN
# 2            WC2N 5BY          GB          London  Greater London
# 3            WC2H 7LH          GB          London  Greater London
# 4             W1D 6QF          GB  City of London  Greater London
#
#   location.country                          location.formattedAddress  \
# 0   United Kingdom  [Whitehall Pl, London, Greater London, SW1A 2B...
# 1   United Kingdom  [3-5 Great Scotland Yard, London, SW1A 2HN, Un...
# 2   United Kingdom  [8 Northumberland Avenue, London, Greater Lond...
# 3   United Kingdom  [31-36 Leicester Square, London, Greater Londo...
# 4   United Kingdom  [Leicester Square, 10 Wardour Street, City of ...
#
#   location.crossStreet venuePage.id location.neighborhood
# 0                  NaN          NaN                   NaN
# 1                  NaN          NaN                   NaN
# 2                  NaN          NaN                   NaN
# 3                  NaN          NaN                   NaN
# 4                  NaN          NaN                   NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in hotels_df.columns if col.startswith('location.')] + ['id']
hotels_df_filtered = hotels_df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
hotels_df_filtered['categories'] = hotels_df_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
hotels_df_filtered.columns = [column.split('.')[-1] for column in hotels_df_filtered.columns]

hotels_df_filtered
# Out:
#                                                  name            categories  \
# 0                                     Corinthia Hotel                 Hotel
# 1   Great Scotland Yard Hotel - In the Unbound Col...                 Hotel
# 2                                 Club Quarters Hotel                 Hotel
# 3              Radisson Blu Edwardian Hampshire Hotel                 Hotel
# 4                                      W London Hotel                 Hotel
# 5                Afternoon Tea at the Corinthia Hotel              Tea Room
# 6                             St. Martin's Lane Hotel                 Hotel
# 7                            Amba Charing Cross Hotel                 Hotel
# 8                                        Hotel Indigo                 Hotel
# 9                                   FIT (W Hotel Gym)  Gym / Fitness Center
# 10               The Piccadilly London West End Hotel                 Hotel
# 11                                St George Inn Hotel   Housing Development
# 12                                     Hotel Chocolat        Chocolate Shop
# 13                                     Amba Hotel Gym  Gym / Fitness Center
# 14                                    Haymarket Hotel                 Hotel
# 15                                Haymarket Hotel Spa                   Spa
# 16                                     Hotel Chocolat        Chocolate Shop
# 17                                        Hotel Cecil         Historic Site
# 18                                    Henrietta Hotel                 Hotel
# 19                                      library hotel                 Hotel
# 20                                  Z Hotel Trafalgar                 Hotel
# 21                             The Z Hotel Piccadilly                 Hotel
# 22                  The 99 Club@St Martins Lane Hotel           Comedy Club
# 23                                     Assembly Hotel                 Hotel
# 24                       Gym @ Every Hotel Piccadilly                   Gym
# 25                      HotelPartner Yield Management                Office
# 26                          The Z Hotel Covent Garden                 Hotel
# 27                             W Hotel Screening Room         Movie Theater
# 28      Global Great Hotels - Investments Real Estate       Business Center
# 29  The Trafalgar St. James London, Curio Collecti...                 Hotel
# 30                      The Grand at Trafalgar Square                 Hotel
# 31                             ESPA Life at Corinthia                   Spa
# 32                               Northumberland House                 Hotel
# 33            hub by Premier Inn London Covent Garden                 Hotel
# 34                                      ESPA Life Gym                   Gym
# 35                                         Blind Spot             Speakeasy
# 36                                      Daniel Galvin    Salon / Barbershop
# 37                                         Court Room           Event Space
# 38                            Sofitel London St James                 Hotel
# 39                           HotelTonight European HQ          Tech Startup
# 40                                       The Northall    English Restaurant
# 41                  Citadines Trafalgar Square London                 Hotel
# 42                                       Lobby Lounge                Lounge
# 43                              The Royal Horseguards                 Hotel
# 44                                 Thistle Piccadilly                 Hotel
# 45                                       The Londoner                 Hotel
# 46                                   Radisson Blu Gym                   Gym
# 47                               One Leicester Street                 Hotel
# 48                                           W Lounge             Hotel Bar
# 49                Premier Inn London Leicester Square                 Hotel
#
#                                       address        lat       lng  \
# 0                                Whitehall Pl  51.506607 -0.124460
# 1                     3-5 Great Scotland Yard  51.506425 -0.126146
# 2                     8 Northumberland Avenue  51.506985 -0.126020
# 3                      31-36 Leicester Square  51.509867 -0.129767
# 4         Leicester Square, 10 Wardour Street  51.510821 -0.131352
# 5                             10 Whitehall Pl  51.506572 -0.124350
# 6                        45 St. Martin'S Lane  51.510526 -0.126705
# 7                           The Strand, Ste 2  51.508216 -0.124564
# 8                          1 Leicester Square  51.510720 -0.130932
# 9                                         NaN  51.510029 -0.131398
# 10                          65 Shaftsbury Ave  51.512156 -0.131767
# 11                         Belgrave Street 25  51.507716 -0.129509
# 12                      Charing Cross Station  51.508081 -0.124401
# 13                                        NaN  51.508312 -0.124669
# 14                               1 Suffolk Pl  51.508267 -0.131315
# 15                            1 Suffolk Place  51.508239 -0.131518
# 16                              78 The Strand  51.510099 -0.122293
# 17                                        NaN  51.510167 -0.121888
# 18                            14 Henrietta St  51.511141 -0.123330
# 19                                        NaN  51.510008 -0.127645
# 20                           53-59 Chandos Pl  51.509965 -0.125388
# 21                                2 Orange St  51.509009 -0.131564
# 22                           At Martin's Lane  51.510430 -0.126499
# 23                  27-31 Charring Cross Road  51.510549 -0.128521
# 24                                        NaN  51.510223 -0.131556
# 25  1 Northumberland Avenue, Trafalgar Square  51.507214 -0.127035
# 26                           31-32 Bedford St  51.511105 -0.124478
# 27                             10 Wardour St.  51.510933 -0.132350
# 28                         133 Cockfosters Rd  51.507086 -0.127909
# 29         2 Spring Gardens, Trafalgar Square  51.507337 -0.129073
# 30                       8 Northumberland Ave  51.507182 -0.126127
# 31                            10 Whitehall Pl  51.506402 -0.125114
# 32                      8 Northumberland Ave.  51.506801 -0.125639
# 33                         110 St Martin's Ln  51.510033 -0.127131
# 34                            10 Whitehall Pl  51.506318 -0.124648
# 35                         45 St. Martin's Ln  51.510430 -0.126747
# 36                            10 Whitehall Pl  51.506609 -0.124471
# 37                            10 Whitehall Pl  51.506283 -0.124621
# 38                           6 Waterloo Place  51.507636 -0.132367
# 39                  146 -148 Clerkenwell Road  51.511238 -0.123505
# 40                     10A Northumberland Ave  51.506599 -0.123821
# 41                   18/21 Northumberland Ave  51.507020 -0.124685
# 42                             1 Whitehall Pl  51.506379 -0.124293
# 43                            2 Whitehall Ct.  51.506127 -0.124224
# 44                                Coventry St  51.510288 -0.131396
# 45                            38 Leicester Sq  51.509862 -0.130213
# 46                         31-36 Leicester Sq  51.509950 -0.129873
# 47                             1 Leicester St  51.511036 -0.131227
# 48                              10 Wardour St  51.510694 -0.131406
# 49           Queens House, 1 Leicester Square  51.511088 -0.130214
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 51.50660672347560...       247   SW1A 2BD
# 1   [{'label': 'display', 'lat': 51.5064253, 'lng'...       157   SW1A 2HN
# 2   [{'label': 'display', 'lat': 51.50698547522388...       131   WC2N 5BY
# 3   [{'label': 'display', 'lat': 51.5098669, 'lng'...       306   WC2H 7LH
# 4   [{'label': 'display', 'lat': 51.510821, 'lng':...       453    W1D 6QF
# 5   [{'label': 'display', 'lat': 51.50657230583427...       256   SW1A 2BD
# 6   [{'label': 'display', 'lat': 51.51052632268574...       356   WC2N 4HX
# 7   [{'label': 'display', 'lat': 51.50821644805786...       241   WC2N 5HX
# 8   [{'label': 'display', 'lat': 51.5107204, 'lng'...       428   WC2H 7NA
# 9   [{'label': 'display', 'lat': 51.51002945140006...       384        NaN
# 10  [{'label': 'display', 'lat': 51.51215571165802...       596    W1D 6EX
# 11  [{'label': 'display', 'lat': 51.507716, 'lng':...       123        NaN
# 12  [{'label': 'display', 'lat': 51.50808137396048...       247   WC2N 5HS
# 13  [{'label': 'display', 'lat': 51.50831237866142...       239        NaN
# 14  [{'label': 'display', 'lat': 51.50826687319245...       261   SW1Y 4HX
# 15  [{'label': 'display', 'lat': 51.50823877036787...       273   SW1Y 4BP
# 16  [{'label': 'display', 'lat': 51.51009906249482...       485   WC2R 0DE
# 17  [{'label': 'display', 'lat': 51.510167, 'lng':...       512   WC2R 0BN
# 18  [{'label': 'display', 'lat': 51.51114060333864...       518   WC2E 8QH
# 19  [{'label': 'display', 'lat': 51.51000814331115...       290        NaN
# 20  [{'label': 'display', 'lat': 51.509965, 'lng':...       330   WC2N 4HS
# 21  [{'label': 'display', 'lat': 51.50900946456780...       316   WC2H 7DF
# 22  [{'label': 'display', 'lat': 51.51043, 'lng': ...       349   WC2N 4HX
# 23  [{'label': 'display', 'lat': 51.51054918955679...       354   WC2H 0LS
# 24  [{'label': 'display', 'lat': 51.510223, 'lng':...       407        W1D
# 25  [{'label': 'display', 'lat': 51.507214, 'lng':...        56   WC2N 5BW
# 26  [{'label': 'display', 'lat': 51.511105, 'lng':...       472   WC2E 9ED
# 27  [{'label': 'display', 'lat': 51.51093257635912...       503    W1D 6QF
# 28  [{'label': 'display', 'lat': 51.50708638980144...        35    EN4 0AA
# 29  [{'label': 'display', 'lat': 51.50733680732381...        88   SW1A 2TS
# 30  [{'label': 'display', 'lat': 51.50718170797866...       118   WC2N 5BY
# 31  [{'label': 'display', 'lat': 51.50640190821809...       216   SW1A 2BD
# 32  [{'label': 'display', 'lat': 51.50680059043122...       163    E12 5HF
# 33  [{'label': 'display', 'lat': 51.5100327, 'lng'...       296   WC2N 4BA
# 34  [{'label': 'display', 'lat': 51.50631843415083...       249        NaN
# 35  [{'label': 'display', 'lat': 51.51042996262026...       345   WC2N 4HX
# 36  [{'label': 'display', 'lat': 51.506609, 'lng':...       246   WC2N 5AE
# 37  [{'label': 'display', 'lat': 51.50628280639648...       252   SW1A 2BD
# 38  [{'label': 'display', 'lat': 51.50763553208714...       317   SW1Y 4AN
# 39  [{'label': 'display', 'lat': 51.51123793552026...       520   EC1R 5DG
# 40  [{'label': 'display', 'lat': 51.50659890641054...       289   WC2N 5AE
# 41  [{'label': 'display', 'lat': 51.50702046674641...       219   WC2N 5EA
# 42  [{'label': 'display', 'lat': 51.50637874867045...       268    SW1 A 2
# 43  [{'label': 'display', 'lat': 51.50612671032344...       285   SW1A 2EJ
# 44  [{'label': 'display', 'lat': 51.51028793352039...       406    W1D 6BZ
# 45  [{'label': 'display', 'lat': 51.50986242418642...       321   WC2H 7DX
# 46  [{'label': 'display', 'lat': 51.50995, 'lng': ...       318   WC2H 7LH
# 47  [{'label': 'display', 'lat': 51.51103591536942...       469   WC2H 7BL
# 48  [{'label': 'display', 'lat': 51.51069429260831...       443    W1D 6QF
# 49  [{'label': 'display', 'lat': 51.5110883, 'lng'...       443   WC2H 7BP
#
#     cc              city           state         country  \
# 0   GB            London  Greater London  United Kingdom
# 1   GB            London             NaN  United Kingdom
# 2   GB            London  Greater London  United Kingdom
# 3   GB            London  Greater London  United Kingdom
# 4   GB    City of London  Greater London  United Kingdom
# 5   GB            London  Greater London  United Kingdom
# 6   GB            London  Greater London  United Kingdom
# 7   GB            London  Greater London  United Kingdom
# 8   GB            London  Greater London  United Kingdom
# 9   GB            London  Greater London  United Kingdom
# 10  GB            London  Greater London  United Kingdom
# 11  GB            London  Greater London  United Kingdom
# 12  GB            London  Greater London  United Kingdom
# 13  GB               NaN             NaN  United Kingdom
# 14  GB            London  Greater London  United Kingdom
# 15  GB            London  Greater London  United Kingdom
# 16  GB            London  Greater London  United Kingdom
# 17  GB            London  Greater London  United Kingdom
# 18  GB            London  Greater London  United Kingdom
# 19  GB               NaN             NaN  United Kingdom
# 20  GB            London  Greater London  United Kingdom
# 21  GB            London  Greater London  United Kingdom
# 22  GB            London  Greater London  United Kingdom
# 23  GB            London  Greater London  United Kingdom
# 24  GB            London  Greater London  United Kingdom
# 25  GB            London  Greater London  United Kingdom
# 26  GB            London  Greater London  United Kingdom
# 27  GB              Soho  Greater London  United Kingdom
# 28  GB     Hertfordshire   Hertfordshire  United Kingdom
# 29  GB            London  Greater London  United Kingdom
# 30  GB            London  Greater London  United Kingdom
# 31  GB            London  Greater London  United Kingdom
# 32  GB            London  Greater London  United Kingdom
# 33  GB            London             NaN  United Kingdom
# 34  GB            London  Greater London  United Kingdom
# 35  GB            London  Greater London  United Kingdom
# 36  GB            London  Greater London  United Kingdom
# 37  GB            London  Greater London  United Kingdom
# 38  GB            London  Greater London  United Kingdom
# 39  GB               NaN             NaN  United Kingdom
# 40  GB            London  Greater London  United Kingdom
# 41  GB     Charing Cross  Greater London  United Kingdom
# 42  GB            London  Greater London  United Kingdom
# 43  GB            London  Greater London  United Kingdom
# 44  GB            London  Greater London  United Kingdom
# 45  GB            London  Greater London  United Kingdom
# 46  GB            London  Greater London  United Kingdom
# 47  GB            London  Greater London  United Kingdom
# 48  GB  Leicester Square  Greater London  United Kingdom
# 49  GB    City of London  Greater London  United Kingdom
#
#                                      formattedAddress            crossStreet  \
# 0   [Whitehall Pl, London, Greater London, SW1A 2B...                    NaN
# 1   [3-5 Great Scotland Yard, London, SW1A 2HN, Un...                    NaN
# 2   [8 Northumberland Avenue, London, Greater Lond...                    NaN
# 3   [31-36 Leicester Square, London, Greater Londo...                    NaN
# 4   [Leicester Square, 10 Wardour Street, City of ...                    NaN
# 5   [10 Whitehall Pl, London, Greater London, SW1A...                    NaN
# 6   [45 St. Martin'S Lane, London, Greater London,...                    NaN
# 7   [The Strand, Ste 2, London, Greater London, WC...                    NaN
# 8   [1 Leicester Square, London, Greater London, W...                    NaN
# 9            [London, Greater London, United Kingdom]                    NaN
# 10  [65 Shaftsbury Ave, London, Greater London, W1...                    NaN
# 11  [Belgrave Street 25 (Near Victoria Station), L...  Near Victoria Station
# 12  [Charing Cross Station (Strand), London, Great...                 Strand
# 13                                   [United Kingdom]                    NaN
# 14  [1 Suffolk Pl, London, Greater London, SW1Y 4H...                    NaN
# 15  [1 Suffolk Place, London, Greater London, SW1Y...                    NaN
# 16  [78 The Strand, London, Greater London, WC2R 0...                    NaN
# 17  [London, Greater London, WC2R 0BN, United King...                    NaN
# 18  [14 Henrietta St, London, Greater London, WC2E...                    NaN
# 19                                   [United Kingdom]                    NaN
# 20  [53-59 Chandos Pl, London, Greater London, WC2...                    NaN
# 21  [2 Orange St, London, Greater London, WC2H 7DF...                    NaN
# 22  [At Martin's Lane, London, Greater London, WC2...                    NaN
# 23  [27-31 Charring Cross Road, London, Greater Lo...                    NaN
# 24      [London, Greater London, W1D, United Kingdom]                    NaN
# 25  [1 Northumberland Avenue, Trafalgar Square, Lo...                    NaN
# 26  [31-32 Bedford St, London, Greater London, WC2...                    NaN
# 27  [10 Wardour St. (at Leicester Sq.), Soho, Grea...       at Leicester Sq.
# 28  [133 Cockfosters Rd, Hertfordshire, EN4 0AA, U...                    NaN
# 29  [2 Spring Gardens, Trafalgar Square, London, G...                    NaN
# 30  [8 Northumberland Ave, London, Greater London,...                    NaN
# 31  [10 Whitehall Pl, London, Greater London, SW1A...                    NaN
# 32  [8 Northumberland Ave., London, Greater London...                    NaN
# 33  [110 St Martin's Ln, London, WC2N 4BA, United ...                    NaN
# 34  [10 Whitehall Pl, London, Greater London, Unit...                    NaN
# 35  [45 St. Martin's Ln, London, Greater London, W...                    NaN
# 36  [10 Whitehall Pl, London, Greater London, WC2N...                    NaN
# 37  [10 Whitehall Pl, London, Greater London, SW1A...                    NaN
# 38  [6 Waterloo Place, St. James's, Greater London...                    NaN
# 39  [146 -148 Clerkenwell Road, EC1R 5DG, United K...                    NaN
# 40  [10A Northumberland Ave (Whitehall Pl), London...           Whitehall Pl
# 41  [18/21 Northumberland Ave, Charing Cross, Grea...                    NaN
# 42  [1 Whitehall Pl, London, Greater London, SW1 A...                    NaN
# 43  [2 Whitehall Ct., London, Greater London, SW1A...                    NaN
# 44  [Coventry St, London, Greater London, W1D 6BZ,...                    NaN
# 45  [38 Leicester Sq, London, Greater London, WC2H...                    NaN
# 46  [31-36 Leicester Sq, London, Greater London, W...                    NaN
# 47  [1 Leicester St, London, Greater London, WC2H ...                    NaN
# 48  [10 Wardour St, Leicester Square, Greater Lond...                    NaN
# 49  [Queens House, 1 Leicester Square, City of Lon...                    NaN
#
#                                 neighborhood                        id
# 0                                        NaN  4d274945d86aa09024d41dc0
# 1                                        NaN  5d53299e9293ba0007f03f86
# 2                                        NaN  4bc54daa6a3e9c7496c8f548
# 3                                        NaN  4ac518b5f964a5209fa020e3
# 4                                        NaN  4ad7ed82f964a520241021e3
# 5                                        NaN  52764ec8498e83fe786a0595
# 6                                        NaN  4ba51d68f964a52030df38e3
# 7                                        NaN  4bc78b3c93bdeee1947f37ae
# 8                                        NaN  5aa19ea5c666663fb5d39a6c
# 9                                        NaN  56fe22b0498ef2d2226413fb
# 10                                       NaN  564c9b99498ec148d934dede
# 11                                       NaN  52acd5a711d293ec4f5f4d18
# 12                                       NaN  58e4ff8ec45ee3187f52bbd6
# 13                                       NaN  5601b040498e5def6d164bc6
# 14                                       NaN  4abcec53f964a520b98720e3
# 15                                       NaN  4ac518d1f964a520e9a620e3
# 16                                       NaN  4bcc5decb6c49c748c8e9391
# 17                                       NaN  5dd7f228caa13c000808171c
# 18                                       NaN  4ace3d9df964a52057cf20e3
# 19                                       NaN  5650d8af498e63f6c44aec00
# 20                                       NaN  5dfcdcad867d0c000889b709
# 21                                       NaN  53a47f8b498ea84d1e81a90e
# 22                                       NaN  5c43911ea0215b003969bd89
# 23                                       NaN  5ad474e725fb7b4523d48bf5
# 24                                       NaN  5a0eea7964c8e11593989ebd
# 25                                       NaN  57a087c9498e4de77af68d8a
# 26                                       NaN  5be85bdba30619002c2931fe
# 27                                       NaN  5051b834e4b08416d819eb27
# 28                                       NaN  5afb9f1b65211f002c89d942
# 29                                       NaN  4af290c7f964a520eee721e3
# 30                                       NaN  4aec417bf964a520b2c521e3
# 31                                       NaN  509e51b6e4b03f3cc1f3f56c
# 32                                       NaN  4b1a4ffef964a520d3e823e3
# 33                                       NaN  54514efd498e59da3cda9ea8
# 34                                       NaN  503a6e8be4b0bd2ec5157d9b
# 35                                       NaN  4ac518bef964a52022a320e3
# 36                                       NaN  5b81715a75dcb7002c755002
# 37                                       NaN  50c5ebe2e4b04a2d9e87a68b
# 38                                       NaN  4ae982def964a520f7b421e3
# 39                                       NaN  518a0ca1498eb20d63bb9b84
# 40                                       NaN  4e13812ecc3f2ee5189898dc
# 41                                       NaN  4b5f733bf964a5200fbb29e3
# 42                                       NaN  4e3e8a721495bf24a5e8f9ff
# 43                                       NaN  4ac518b4f964a52083a020e3
# 44                                       NaN  4adf93a5f964a520c17b21e3
# 45                          Leicester Square  5ff60aa53ecb1c16167e311d
# 46                                       NaN  5881e9efcc5b6a08df5a8768
# 47                                       NaN  523a6fb611d2d37317621724
# 48  Leicester Square, London, Greater London  4d601b5d1939a35d959b1dee
# 49                                       NaN  4faea95de4b0604807fb2a4a

# %%
#keeping only venues with the category "Hotel"

hotels_df_filtered = hotels_df_filtered[hotels_df_filtered.categories == 'Hotel']
hotels_df_filtered.head(10)
# Out:
#                                                  name categories  \
# 0                                     Corinthia Hotel      Hotel
# 1   Great Scotland Yard Hotel - In the Unbound Col...      Hotel
# 2                                 Club Quarters Hotel      Hotel
# 3              Radisson Blu Edwardian Hampshire Hotel      Hotel
# 4                                      W London Hotel      Hotel
# 6                             St. Martin's Lane Hotel      Hotel
# 7                            Amba Charing Cross Hotel      Hotel
# 8                                        Hotel Indigo      Hotel
# 10               The Piccadilly London West End Hotel      Hotel
# 14                                    Haymarket Hotel      Hotel
#
#                                 address        lat       lng  \
# 0                          Whitehall Pl  51.506607 -0.124460
# 1               3-5 Great Scotland Yard  51.506425 -0.126146
# 2               8 Northumberland Avenue  51.506985 -0.126020
# 3                31-36 Leicester Square  51.509867 -0.129767
# 4   Leicester Square, 10 Wardour Street  51.510821 -0.131352
# 6                  45 St. Martin'S Lane  51.510526 -0.126705
# 7                     The Strand, Ste 2  51.508216 -0.124564
# 8                    1 Leicester Square  51.510720 -0.130932
# 10                    65 Shaftsbury Ave  51.512156 -0.131767
# 14                         1 Suffolk Pl  51.508267 -0.131315
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 51.50660672347560...       247   SW1A 2BD
# 1   [{'label': 'display', 'lat': 51.5064253, 'lng'...       157   SW1A 2HN
# 2   [{'label': 'display', 'lat': 51.50698547522388...       131   WC2N 5BY
# 3   [{'label': 'display', 'lat': 51.5098669, 'lng'...       306   WC2H 7LH
# 4   [{'label': 'display', 'lat': 51.510821, 'lng':...       453    W1D 6QF
# 6   [{'label': 'display', 'lat': 51.51052632268574...       356   WC2N 4HX
# 7   [{'label': 'display', 'lat': 51.50821644805786...       241   WC2N 5HX
# 8   [{'label': 'display', 'lat': 51.5107204, 'lng'...       428   WC2H 7NA
# 10  [{'label': 'display', 'lat': 51.51215571165802...       596    W1D 6EX
# 14  [{'label': 'display', 'lat': 51.50826687319245...       261   SW1Y 4HX
#
#     cc            city           state         country  \
# 0   GB          London  Greater London  United Kingdom
# 1   GB          London             NaN  United Kingdom
# 2   GB          London  Greater London  United Kingdom
# 3   GB          London  Greater London  United Kingdom
# 4   GB  City of London  Greater London  United Kingdom
# 6   GB          London  Greater London  United Kingdom
# 7   GB          London  Greater London  United Kingdom
# 8   GB          London  Greater London  United Kingdom
# 10  GB          London  Greater London  United Kingdom
# 14  GB          London  Greater London  United Kingdom
#
#                                      formattedAddress crossStreet  \
# 0   [Whitehall Pl, London, Greater London, SW1A 2B...         NaN
# 1   [3-5 Great Scotland Yard, London, SW1A 2HN, Un...         NaN
# 2   [8 Northumberland Avenue, London, Greater Lond...         NaN
# 3   [31-36 Leicester Square, London, Greater Londo...         NaN
# 4   [Leicester Square, 10 Wardour Street, City of ...         NaN
# 6   [45 St. Martin'S Lane, London, Greater London,...         NaN
# 7   [The Strand, Ste 2, London, Greater London, WC...         NaN
# 8   [1 Leicester Square, London, Greater London, W...         NaN
# 10  [65 Shaftsbury Ave, London, Greater London, W1...         NaN
# 14  [1 Suffolk Pl, London, Greater London, SW1Y 4H...         NaN
#
#    neighborhood                        id
# 0           NaN  4d274945d86aa09024d41dc0
# 1           NaN  5d53299e9293ba0007f03f86
# 2           NaN  4bc54daa6a3e9c7496c8f548
# 3           NaN  4ac518b5f964a5209fa020e3
# 4           NaN  4ad7ed82f964a520241021e3
# 6           NaN  4ba51d68f964a52030df38e3
# 7           NaN  4bc78b3c93bdeee1947f37ae
# 8           NaN  5aa19ea5c666663fb5d39a6c
# 10          NaN  564c9b99498ec148d934dede
# 14          NaN  4abcec53f964a520b98720e3

# %%
#resetting index

hotels_df_filtered.reset_index(drop=True, inplace=True)
hotels_df_filtered.head(10)
# Out:
#                                                 name categories  \
# 0                                    Corinthia Hotel      Hotel
# 1  Great Scotland Yard Hotel - In the Unbound Col...      Hotel
# 2                                Club Quarters Hotel      Hotel
# 3             Radisson Blu Edwardian Hampshire Hotel      Hotel
# 4                                     W London Hotel      Hotel
# 5                            St. Martin's Lane Hotel      Hotel
# 6                           Amba Charing Cross Hotel      Hotel
# 7                                       Hotel Indigo      Hotel
# 8               The Piccadilly London West End Hotel      Hotel
# 9                                    Haymarket Hotel      Hotel
#
#                                address        lat       lng  \
# 0                         Whitehall Pl  51.506607 -0.124460
# 1              3-5 Great Scotland Yard  51.506425 -0.126146
# 2              8 Northumberland Avenue  51.506985 -0.126020
# 3               31-36 Leicester Square  51.509867 -0.129767
# 4  Leicester Square, 10 Wardour Street  51.510821 -0.131352
# 5                 45 St. Martin'S Lane  51.510526 -0.126705
# 6                    The Strand, Ste 2  51.508216 -0.124564
# 7                   1 Leicester Square  51.510720 -0.130932
# 8                    65 Shaftsbury Ave  51.512156 -0.131767
# 9                         1 Suffolk Pl  51.508267 -0.131315
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 51.50660672347560...       247   SW1A 2BD  GB
# 1  [{'label': 'display', 'lat': 51.5064253, 'lng'...       157   SW1A 2HN  GB
# 2  [{'label': 'display', 'lat': 51.50698547522388...       131   WC2N 5BY  GB
# 3  [{'label': 'display', 'lat': 51.5098669, 'lng'...       306   WC2H 7LH  GB
# 4  [{'label': 'display', 'lat': 51.510821, 'lng':...       453    W1D 6QF  GB
# 5  [{'label': 'display', 'lat': 51.51052632268574...       356   WC2N 4HX  GB
# 6  [{'label': 'display', 'lat': 51.50821644805786...       241   WC2N 5HX  GB
# 7  [{'label': 'display', 'lat': 51.5107204, 'lng'...       428   WC2H 7NA  GB
# 8  [{'label': 'display', 'lat': 51.51215571165802...       596    W1D 6EX  GB
# 9  [{'label': 'display', 'lat': 51.50826687319245...       261   SW1Y 4HX  GB
#
#              city           state         country  \
# 0          London  Greater London  United Kingdom
# 1          London             NaN  United Kingdom
# 2          London  Greater London  United Kingdom
# 3          London  Greater London  United Kingdom
# 4  City of London  Greater London  United Kingdom
# 5          London  Greater London  United Kingdom
# 6          London  Greater London  United Kingdom
# 7          London  Greater London  United Kingdom
# 8          London  Greater London  United Kingdom
# 9          London  Greater London  United Kingdom
#
#                                     formattedAddress crossStreet neighborhood  \
# 0  [Whitehall Pl, London, Greater London, SW1A 2B...         NaN          NaN
# 1  [3-5 Great Scotland Yard, London, SW1A 2HN, Un...         NaN          NaN
# 2  [8 Northumberland Avenue, London, Greater Lond...         NaN          NaN
# 3  [31-36 Leicester Square, London, Greater Londo...         NaN          NaN
# 4  [Leicester Square, 10 Wardour Street, City of ...         NaN          NaN
# 5  [45 St. Martin'S Lane, London, Greater London,...         NaN          NaN
# 6  [The Strand, Ste 2, London, Greater London, WC...         NaN          NaN
# 7  [1 Leicester Square, London, Greater London, W...         NaN          NaN
# 8  [65 Shaftsbury Ave, London, Greater London, W1...         NaN          NaN
# 9  [1 Suffolk Pl, London, Greater London, SW1Y 4H...         NaN          NaN
#
#                          id
# 0  4d274945d86aa09024d41dc0
# 1  5d53299e9293ba0007f03f86
# 2  4bc54daa6a3e9c7496c8f548
# 3  4ac518b5f964a5209fa020e3
# 4  4ad7ed82f964a520241021e3
# 5  4ba51d68f964a52030df38e3
# 6  4bc78b3c93bdeee1947f37ae
# 7  5aa19ea5c666663fb5d39a6c
# 8  564c9b99498ec148d934dede
# 9  4abcec53f964a520b98720e3

# %%
#creating a map to view the resulting hotels and their locations
hotels_map = folium.Map(location=[london_lat, london_lon], zoom_start=15) # generate map centred around London

# add the hotels as blue circle markers
for lat, lng, label in zip(hotels_df_filtered.lat, hotels_df_filtered.lng, hotels_df_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(hotels_map)

# display map
hotels_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_3152e99dfb0346668a3e56e8f3ae7d5d%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3152e99dfb0346668a3e56e8f3ae7d5d%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_3152e99dfb0346668a3e56e8f3ae7d5d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_3152e99dfb0346668a3e56e8f3ae7d5d%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5074%2C%20-0.1278%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_7a266bda7abc451ab77d4a75578dc80f%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%2 ...

# %%
#How many hotels are there near london city center?
hotels_df_filtered.shape
# Out:
# (27, 16)

# %%
#prepare hotels dataframe for clustering

#adding an ID number to each venue will help in re-assembling the data after clustering
id_n = list(range(1,len(hotels_df_filtered)+1))
hotels_df_filtered['id_n'] = id_n
hotels_df_filtered.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                                                 name categories  \
# 0                                    Corinthia Hotel      Hotel
# 1  Great Scotland Yard Hotel - In the Unbound Col...      Hotel
# 2                                Club Quarters Hotel      Hotel
# 3             Radisson Blu Edwardian Hampshire Hotel      Hotel
# 4                                     W London Hotel      Hotel
#
#                                address        lat       lng  \
# 0                         Whitehall Pl  51.506607 -0.124460
# 1              3-5 Great Scotland Yard  51.506425 -0.126146
# 2              8 Northumberland Avenue  51.506985 -0.126020
# 3               31-36 Leicester Square  51.509867 -0.129767
# 4  Leicester Square, 10 Wardour Street  51.510821 -0.131352
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 51.50660672347560...       247   SW1A 2BD  GB
# 1  [{'label': 'display', 'lat': 51.5064253, 'lng'...       157   SW1A 2HN  GB
# 2  [{'label': 'display', 'lat': 51.50698547522388...       131   WC2N 5BY  GB
# 3  [{'label': 'display', 'lat': 51.5098669, 'lng'...       306   WC2H 7LH  GB
# 4  [{'label': 'display', 'lat': 51.510821, 'lng':...       453    W1D 6QF  GB
#
#              city           state         country  \
# 0          London  Greater London  United Kingdom
# 1          London             NaN  United Kingdom
# 2          London  Greater London  United Kingdom
# 3          London  Greater London  United Kingdom
# 4  City of London  Greater London  United Kingdom
#
#                                     formattedAddress crossStreet neighborhood  \
# 0  [Whitehall Pl, London, Greater London, SW1A 2B...         NaN          NaN
# 1  [3-5 Great Scotland Yard, London, SW1A 2HN, Un...         NaN          NaN
# 2  [8 Northumberland Avenue, London, Greater Lond...         NaN          NaN
# 3  [31-36 Leicester Square, London, Greater Londo...         NaN          NaN
# 4  [Leicester Square, 10 Wardour Street, City of ...         NaN          NaN
#
#                          id  id_n
# 0  4d274945d86aa09024d41dc0     1
# 1  5d53299e9293ba0007f03f86     2
# 2  4bc54daa6a3e9c7496c8f548     3
# 3  4ac518b5f964a5209fa020e3     4
# 4  4ad7ed82f964a520241021e3     5

# %%
# The dataset that will be used in K-Means clustering
X=hotels_df_filtered.loc[:,['id_n','lat','lng']]
X.head(10)
# Out:
#    id_n        lat       lng
# 0     1  51.506607 -0.124460
# 1     2  51.506425 -0.126146
# 2     3  51.506985 -0.126020
# 3     4  51.509867 -0.129767
# 4     5  51.510821 -0.131352
# 5     6  51.510526 -0.126705
# 6     7  51.508216 -0.124564
# 7     8  51.510720 -0.130932
# 8     9  51.512156 -0.131767
# 9    10  51.508267 -0.131315

# %%
#clustering the hotels based on their locations 
kmeans = KMeans(n_clusters = 3, init ='k-means++') # hotels will be clustered in 3 groups
kmeans.fit(X[X.columns[1:3]]) # Compute k-means clustering.
X['cluster_label'] = kmeans.fit_predict(X[X.columns[1:3]])
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(X[X.columns[1:3]]) # Labels of each point
centers = kmeans.cluster_centers_
print(centers) #to show coordinates of the center for each cluster 
X.head(10)
# Out:
# [[51.51046296 -0.12577928]
#  [51.50989511 -0.1307468 ]
#  [51.50692043 -0.12523318]]
#    id_n        lat       lng  cluster_label
# 0     1  51.506607 -0.124460              2
# 1     2  51.506425 -0.126146              2
# 2     3  51.506985 -0.126020              2
# 3     4  51.509867 -0.129767              1
# 4     5  51.510821 -0.131352              1
# 5     6  51.510526 -0.126705              0
# 6     7  51.508216 -0.124564              2
# 7     8  51.510720 -0.130932              1
# 8     9  51.512156 -0.131767              1
# 9    10  51.508267 -0.131315              1

# %%
#adding the cluster label to each venue in the hotels data frame
X = X[['id_n','cluster_label']]
clustered_hotels = hotels_df_filtered.merge(X, left_on='id_n', right_on='id_n')
clustered_hotels.head()
# Out:
#                                                 name categories  \
# 0                                    Corinthia Hotel      Hotel
# 1  Great Scotland Yard Hotel - In the Unbound Col...      Hotel
# 2                                Club Quarters Hotel      Hotel
# 3             Radisson Blu Edwardian Hampshire Hotel      Hotel
# 4                                     W London Hotel      Hotel
#
#                                address        lat       lng  \
# 0                         Whitehall Pl  51.506607 -0.124460
# 1              3-5 Great Scotland Yard  51.506425 -0.126146
# 2              8 Northumberland Avenue  51.506985 -0.126020
# 3               31-36 Leicester Square  51.509867 -0.129767
# 4  Leicester Square, 10 Wardour Street  51.510821 -0.131352
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 51.50660672347560...       247   SW1A 2BD  GB
# 1  [{'label': 'display', 'lat': 51.5064253, 'lng'...       157   SW1A 2HN  GB
# 2  [{'label': 'display', 'lat': 51.50698547522388...       131   WC2N 5BY  GB
# 3  [{'label': 'display', 'lat': 51.5098669, 'lng'...       306   WC2H 7LH  GB
# 4  [{'label': 'display', 'lat': 51.510821, 'lng':...       453    W1D 6QF  GB
#
#              city           state         country  \
# 0          London  Greater London  United Kingdom
# 1          London             NaN  United Kingdom
# 2          London  Greater London  United Kingdom
# 3          London  Greater London  United Kingdom
# 4  City of London  Greater London  United Kingdom
#
#                                     formattedAddress crossStreet neighborhood  \
# 0  [Whitehall Pl, London, Greater London, SW1A 2B...         NaN          NaN
# 1  [3-5 Great Scotland Yard, London, SW1A 2HN, Un...         NaN          NaN
# 2  [8 Northumberland Avenue, London, Greater Lond...         NaN          NaN
# 3  [31-36 Leicester Square, London, Greater Londo...         NaN          NaN
# 4  [Leicester Square, 10 Wardour Street, City of ...         NaN          NaN
#
#                          id  id_n  cluster_label
# 0  4d274945d86aa09024d41dc0     1              2
# 1  5d53299e9293ba0007f03f86     2              2
# 2  4bc54daa6a3e9c7496c8f548     3              2
# 3  4ac518b5f964a5209fa020e3     4              1
# 4  4ad7ed82f964a520241021e3     5              1

# %%
#map showing each hotel with different color based on the cluster
map_clusters = folium.Map(location=[london_lat, london_lon], zoom_start=15)

# add markers to the map
marker_colors = ['red','green','blue']
for lat, lon, poi, cluster in zip(clustered_hotels['lat'], clustered_hotels['lng'], clustered_hotels['name'], clustered_hotels['cluster_label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=marker_colors[cluster],
        fill=True,
        fill_color=marker_colors[cluster],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters #show map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_5798dd4359874963a0bb10bc67739a03%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5798dd4359874963a0bb10bc67739a03%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_5798dd4359874963a0bb10bc67739a03%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_5798dd4359874963a0bb10bc67739a03%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5074%2C%20-0.1278%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_e7c4b40075b34433bdf4faaa884f1236%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%2 ...

# %%
#putting the center of each cluster in a dataframe for later analysis
centers_df = pd.DataFrame(centers, columns =['c_lat', 'c_lon'])
cluster_label = list(range(0,3))
centers_df['cluster_label'] = cluster_label
centers_df
# Out:
#        c_lat     c_lon  cluster_label
# 0  51.510463 -0.125779              0
# 1  51.509895 -0.130747              1
# 2  51.506920 -0.125233              2

# %%
#map of centers
map_centers = folium.Map(location=[london_lat, london_lon], zoom_start=15)

# add markers to the map in different colors according to cluster
marker_colors = ['red','green','blue']
for lat, lon, poi, cluster in zip(centers_df['c_lat'], centers_df['c_lon'], centers_df['cluster_label'], centers_df['cluster_label']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=marker_colors[cluster],
        fill=True,
        fill_color=marker_colors[cluster],
        fill_opacity=0.7).add_to(map_centers)
       
map_centers #display the map showing 3 markers, one for each cluster
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_4f2ac582c82f4d1e94fc2ed6c6d383b7%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4f2ac582c82f4d1e94fc2ed6c6d383b7%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_4f2ac582c82f4d1e94fc2ed6c6d383b7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_4f2ac582c82f4d1e94fc2ed6c6d383b7%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5074%2C%20-0.1278%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_8b448370c2644b11929e3ac8a00b4bc5%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%2 ...

# %% [markdown]
# <h2>Getting the restaurants data form Foursquare and analysing it</h2>

# %% [markdown]
# In this section, we will call foursquare API again and call for trending venues around london city center using the "explore" call, then we will clean the data, keep restaurants only, and classify these restaurants to one of the clusters created earlier using KNN classification.
#
# To do this we will use the centers data created before as a training set for KNN, then we will predict the cluster to which each restaurant belongs to by finding the nearest center.

# %%
#creating the url to call on foursquare API

limit_restaurants = 500

url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    london_lat, 
    london_lon, 
    radius, 
    limit_restaurants)
url2
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=HU5FWCR5TTHNPOTBIX5DN4AA5OGWV2RXJCUAEXEA5URYXYQF&client_secret=5FSAEAC5ZZOR4VJTYUKEWIHOIYBZ1LHMF05CIOGOT23VIJRD&v=20181216&ll=51.5074,-0.1278&radius=500&limit=500'

# %%
#sving the results
results2 = requests.get(url2).json()

# %%
#getting the needed data and put it in a pandas dataframe
restaurants = results2['response']['groups'][0]['items']
    
restaurants_df = json_normalize(restaurants) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
restaurants_df = restaurants_df.loc[:, filtered_columns]

# filter the category for each row
restaurants_df['venue.categories'] = restaurants_df.apply(get_category_type, axis=1)

# clean columns
restaurants_df.columns = [col.split(".")[-1] for col in restaurants_df.columns]

restaurants_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
#                                                  name  \
# 0                                    National Gallery
# 1                                    Trafalgar Square
# 2                      East Trafalgar Square Fountain
# 3                     Sainsbury Wing National Gallery
# 4                                     Corinthia Hotel
# 5                           National Portrait Gallery
# 6                                     Nelson's Column
# 7                              Trafalgar Square Lions
# 8   Great Scotland Yard Hotel - In the Unbound Col...
# 9                                           Barrafina
# 10                                 Tandoor Chop House
# 11                                    Haymarket Hotel
# 12                             Kerridge’s Bar & Grill
# 13                             English National Opera
# 14               Institute of Contemporary Arts (ICA)
# 15                              Her Majesty's Theatre
# 16                                           The Harp
# 17                                Horse Guards Parade
# 18                                  Gordon's Wine Bar
# 19                                 Civil Service Club
# 20                                     Admiralty Arch
# 21                            Sofitel London St James
# 22                                          Five Guys
# 23                                        Thai Square
# 24                                            Amorino
# 25                               Notes Music & Coffee
# 26                                Dover Street Market
# 27                                     Mall Galleries
# 28                                  Whitehall Gardens
# 29                                       Japan Centre
# 30                            Leicester Square Garden
# 31                                         ICA Cinema
# 32                                        Ole & Steen
# 33                                     The LEGO Store
# 34                        Victoria Embankment Gardens
# 35                                   Leicester Square
# 36                                              Milos
# 37                                The Whisky Exchange
# 38                                     Salt 'n Pepper
# 39                                             So Spa
# 40                                         Fernando's
# 41                                             Wahaca
# 42                                    Sandwich Centre
# 43                                    Garrick Theatre
# 44                            Prince of Wales Theatre
# 45                                             Scully
# 46                                            WA Cafe
# 47                                    Guards Memorial
# 48                                          Superdrug
# 49                            Theatre Royal Haymarket
# 50                                      The Alchemist
# 51               The Original London Sightseeing Tour
# 52                              The London Beer House
# 53                                          Kanada-Ya
# 54                                          Flat Iron
# 55                                             Wasabi
# 56                                             Brumus
# 57                                            Nando's
# 58                                            Amorino
# 59                             The Z Hotel Piccadilly
# 60                              Harold Pinter Theatre
# 61                                    Adelphi Theatre
# 62                              Prince Charles Cinema
# 63                                  Smith & Wollensky
# 64                                      Pret A Manger
# 65                            Pall Mall Fine Wine Bar
# 66                                         Santa Nata
# 67                                        M&M's World
# 68                                     Sticks'n'Sushi
# 69                                     CoCo Ichibanya
# 70                           Leicester Square Kitchen
# 71                                           wagamama
# 72                                        Porterhouse
# 73                                   DW Fitness First
# 74                                           Frenchie
# 75                                               Paul
# 76                                The Travellers Club
# 77                                     Waterloo Place
# 78                                              Rules
# 79                                       St James Bar
# 80                                   Burger & Lobster
# 81                                        The Rooftop
# 82                            Rochelle Canteen at ICA
# 83                                            Aquavit
# 84                                       Shoryu Ramen
# 85                                          Cineworld
# 86                              Naval & Military Club
# 87                                  Comptoir Libanais
# 88                                    The Rose Lounge
# 89                                     W London Hotel
# 90                                     Pizza Pilgrims
# 91                                              Byron
# 92                                 Tattershall Castle
# 93                                        Good Friend
# 94                                            Machiya
# 95                                         Farzi Cafe
# 96                                    Waxy O'Connor's
# 97                                      Orient London
# 98                                 Vaudeville Theatre
# 99                                    St James's Café
#
#                     categories        lat       lng
# 0                   Art Museum  51.508876 -0.128478
# 1                        Plaza  51.507987 -0.128048
# 2                     Fountain  51.508088 -0.127700
# 3                   Art Museum  51.508384 -0.129001
# 4                        Hotel  51.506607 -0.124460
# 5                  Art Gallery  51.509438 -0.128032
# 6          Monument / Landmark  51.507744 -0.127931
# 7            Outdoor Sculpture  51.507641 -0.127888
# 8                        Hotel  51.506425 -0.126146
# 9           Spanish Restaurant  51.509427 -0.125894
# 10     North Indian Restaurant  51.509192 -0.125638
# 11                       Hotel  51.508267 -0.131315
# 12                  Restaurant  51.506728 -0.124520
# 13                 Opera House  51.509804 -0.126945
# 14                 Art Gallery  51.506265 -0.130817
# 15                     Theater  51.508289 -0.131641
# 16                         Pub  51.509719 -0.125943
# 17                       Plaza  51.504847 -0.126590
# 18                    Wine Bar  51.507911 -0.123293
# 19                 Social Club  51.506539 -0.125609
# 20         Monument / Landmark  51.506826 -0.128789
# 21                       Hotel  51.507636 -0.132367
# 22                Burger Joint  51.508520 -0.124363
# 23             Thai Restaurant  51.507656 -0.129830
# 24              Ice Cream Shop  51.510427 -0.128401
# 25                 Coffee Shop  51.509696 -0.126985
# 26                    Boutique  51.508981 -0.131867
# 27                 Art Gallery  51.506370 -0.129776
# 28                      Garden  51.506354 -0.122900
# 29         Japanese Restaurant  51.509761 -0.131273
# 30                      Garden  51.510361 -0.130127
# 31         Indie Movie Theater  51.506018 -0.131068
# 32                      Bakery  51.509196 -0.132788
# 33            Toy / Game Store  51.510391 -0.130997
# 34                      Garden  51.508135 -0.122079
# 35                       Plaza  51.510519 -0.130098
# 36            Greek Restaurant  51.508117 -0.133341
# 37                Liquor Store  51.509974 -0.123713
# 38        Pakistani Restaurant  51.509480 -0.129968
# 39                         Spa  51.507601 -0.132690
# 40              Breakfast Spot  51.510839 -0.127045
# 41          Mexican Restaurant  51.510337 -0.124600
# 42              Sandwich Place  51.508174 -0.132451
# 43                     Theater  51.510044 -0.128082
# 44                     Theater  51.510132 -0.131594
# 45                  Restaurant  51.508744 -0.133083
# 46                        Café  51.511009 -0.126614
# 47         Monument / Landmark  51.504595 -0.129438
# 48                    Pharmacy  51.509174 -0.124054
# 49                     Theater  51.508579 -0.131204
# 50                Cocktail Bar  51.511458 -0.126955
# 51               Tour Provider  51.508011 -0.130052
# 52                         Bar  51.508214 -0.132578
# 53            Ramen Restaurant  51.509359 -0.132215
# 54                  Steakhouse  51.510841 -0.124093
# 55            Sushi Restaurant  51.507690 -0.122953
# 56           French Restaurant  51.508198 -0.131485
# 57       Portuguese Restaurant  51.510325 -0.124604
# 58              Ice Cream Shop  51.511510 -0.125794
# 59                       Hotel  51.509009 -0.131564
# 60                     Theater  51.509443 -0.131644
# 61                     Theater  51.510383 -0.123068
# 62         Indie Movie Theater  51.511529 -0.130269
# 63                  Steakhouse  51.509557 -0.122241
# 64              Sandwich Place  51.508232 -0.130062
# 65                    Wine Bar  51.507660 -0.132015
# 66                      Bakery  51.511016 -0.126260
# 67                 Candy Store  51.510599 -0.131149
# 68            Sushi Restaurant  51.511038 -0.123655
# 69   Japanese Curry Restaurant  51.511875 -0.127809
# 70          Mexican Restaurant  51.509938 -0.129736
# 71            Asian Restaurant  51.510792 -0.124721
# 72                   Irish Pub  51.510410 -0.123653
# 73        Gym / Fitness Center  51.510077 -0.123848
# 74           French Restaurant  51.510908 -0.124035
# 75                      Bakery  51.511226 -0.125000
# 76                      Lounge  51.506654 -0.132939
# 77                       Plaza  51.507235 -0.132530
# 78          English Restaurant  51.510793 -0.123132
# 79                Cocktail Bar  51.507442 -0.132402
# 80          Seafood Restaurant  51.511029 -0.131605
# 81                Cocktail Bar  51.507335 -0.129216
# 82          English Restaurant  51.506258 -0.130640
# 83  Modern European Restaurant  51.508812 -0.133335
# 84            Ramen Restaurant  51.508390 -0.133551
# 85                   Multiplex  51.511077 -0.130600
# 86                 Event Space  51.508180 -0.134463
# 87         Lebanese Restaurant  51.508991 -0.132293
# 88                    Tea Room  51.507491 -0.132574
# 89                       Hotel  51.510821 -0.131352
# 90                 Pizza Place  51.511562 -0.126550
# 91                Burger Joint  51.508871 -0.131699
# 92                         Pub  51.504574 -0.122543
# 93         Fried Chicken Joint  51.511751 -0.128773
# 94         Japanese Restaurant  51.509413 -0.131994
# 95           Indian Restaurant  51.508403 -0.132205
# 96                   Irish Pub  51.510715 -0.132489
# 97          Chinese Restaurant  51.510958 -0.131705
# 98                     Theater  51.510129 -0.122269
# 99                        Café  51.503998 -0.131390

# %%
#number of venues recieved
restaurants_df.shape
# Out:
# (100, 4)

# %%
#keeping only the venues with categories containing "Restaurant"
restaurants_df_cleaned = restaurants_df[restaurants_df['categories'].str.contains('Restaurant')].reset_index(drop=True)
print(restaurants_df_cleaned.shape) #number of restaurants
restaurants_df_cleaned.head()
# Out:
# (27, 4)
#                      name               categories        lat       lng
# 0               Barrafina       Spanish Restaurant  51.509427 -0.125894
# 1      Tandoor Chop House  North Indian Restaurant  51.509192 -0.125638
# 2  Kerridge’s Bar & Grill               Restaurant  51.506728 -0.124520
# 3             Thai Square          Thai Restaurant  51.507656 -0.129830
# 4            Japan Centre      Japanese Restaurant  51.509761 -0.131273

# %%
#creating a map of restaurants
restaurants_map = folium.Map(location=[london_lat, london_lon], zoom_start=15) # generate map centred around London

# add the hotels as yellow circle markers
for lat, lng, label in zip(restaurants_df_cleaned.lat, restaurants_df_cleaned.lng, restaurants_df_cleaned.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='yellow',
        popup=label,
        fill = True,
        fill_color='yellow',
        fill_opacity=0.6
    ).add_to(restaurants_map)

# display map
restaurants_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_ca8f19da078b4358bf70b8bd647baf33%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ca8f19da078b4358bf70b8bd647baf33%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_ca8f19da078b4358bf70b8bd647baf33%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_ca8f19da078b4358bf70b8bd647baf33%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5074%2C%20-0.1278%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_f4acc4db818a412f86be4a0206afd003%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%2 ...

# %%
#preparing the data that will be used in KNN classification
Xhat=restaurants_df_cleaned.loc[:,['lat','lng']] #classification based on the location coordinates
print(Xhat.shape) #number of restaurants
Xhat.head(10) #show dataframe
# Out:
# (27, 2)
#          lat       lng
# 0  51.509427 -0.125894
# 1  51.509192 -0.125638
# 2  51.506728 -0.124520
# 3  51.507656 -0.129830
# 4  51.509761 -0.131273
# 5  51.508117 -0.133341
# 6  51.509480 -0.129968
# 7  51.510337 -0.124600
# 8  51.508744 -0.133083
# 9  51.509359 -0.132215

# %%
#the centers dataframe to be used for training KNN
centers_df
# Out:
#        c_lat     c_lon  cluster_label
# 0  51.510463 -0.125779              0
# 1  51.509895 -0.130747              1
# 2  51.506920 -0.125233              2

# %%
#selecting classification features and target variable
X_train = centers_df[['c_lat', 'c_lon']].values
Y_train = centers_df['cluster_label']

# %%
#importing KNN library
from sklearn.neighbors import KNeighborsClassifier

# %%
k = 1 #classification based on the nearest center
#Train Model and Predict  
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,Y_train)
neigh
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
#classify the restaurants based on the model created
yhat = neigh.predict(Xhat)
yhat[0:5]
# Out:
# array([0, 0, 2, 1, 1])

# %%
#putting the results in a dataframe
KNN_results = pd.DataFrame(yhat, columns=['class'])
KNN_results
# Out:
#     class
# 0       0
# 1       0
# 2       2
# 3       1
# 4       1
# 5       1
# 6       1
# 7       0
# 8       1
# 9       1
# 10      2
# 11      1
# 12      0
# 13      0
# 14      0
# 15      1
# 16      0
# 17      0
# 18      0
# 19      1
# 20      1
# 21      1
# 22      1
# 23      1
# 24      1
# 25      1
# 26      1

# %%
#joining the results with the restaurants dataframe
restaurants_classified = pd.concat([restaurants_df_cleaned, KNN_results], axis=1, sort=False)

# %%
#view resulting dataframe
restaurants_classified
# Out:
#                         name                  categories        lat       lng  \
# 0                  Barrafina          Spanish Restaurant  51.509427 -0.125894
# 1         Tandoor Chop House     North Indian Restaurant  51.509192 -0.125638
# 2     Kerridge’s Bar & Grill                  Restaurant  51.506728 -0.124520
# 3                Thai Square             Thai Restaurant  51.507656 -0.129830
# 4               Japan Centre         Japanese Restaurant  51.509761 -0.131273
# 5                      Milos            Greek Restaurant  51.508117 -0.133341
# 6             Salt 'n Pepper        Pakistani Restaurant  51.509480 -0.129968
# 7                     Wahaca          Mexican Restaurant  51.510337 -0.124600
# 8                     Scully                  Restaurant  51.508744 -0.133083
# 9                  Kanada-Ya            Ramen Restaurant  51.509359 -0.132215
# 10                    Wasabi            Sushi Restaurant  51.507690 -0.122953
# 11                    Brumus           French Restaurant  51.508198 -0.131485
# 12                   Nando's       Portuguese Restaurant  51.510325 -0.124604
# 13            Sticks'n'Sushi            Sushi Restaurant  51.511038 -0.123655
# 14            CoCo Ichibanya   Japanese Curry Restaurant  51.511875 -0.127809
# 15  Leicester Square Kitchen          Mexican Restaurant  51.509938 -0.129736
# 16                  wagamama            Asian Restaurant  51.510792 -0.124721
# 17                  Frenchie           French Restaurant  51.510908 -0.124035
# 18                     Rules          English Restaurant  51.510793 -0.123132
# 19          Burger & Lobster          Seafood Restaurant  51.511029 -0.131605
# 20   Rochelle Canteen at ICA          English Restaurant  51.506258 -0.130640
# 21                   Aquavit  Modern European Restaurant  51.508812 -0.133335
# 22              Shoryu Ramen            Ramen Restaurant  51.508390 -0.133551
# 23         Comptoir Libanais         Lebanese Restaurant  51.508991 -0.132293
# 24                   Machiya         Japanese Restaurant  51.509413 -0.131994
# 25                Farzi Cafe           Indian Restaurant  51.508403 -0.132205
# 26             Orient London          Chinese Restaurant  51.510958 -0.131705
#
#     class
# 0       0
# 1       0
# 2       2
# 3       1
# 4       1
# 5       1
# 6       1
# 7       0
# 8       1
# 9       1
# 10      2
# 11      1
# 12      0
# 13      0
# 14      0
# 15      1
# 16      0
# 17      0
# 18      0
# 19      1
# 20      1
# 21      1
# 22      1
# 23      1
# 24      1
# 25      1
# 26      1

# %%
#show restaurante in each area in different color
map_rest_class = folium.Map(location=[london_lat, london_lon], zoom_start=15)

# add markers to the map
marker_colors = ['red','green','blue']
for lat, lon, poi, cluster in zip(restaurants_classified['lat'], restaurants_classified['lng'], restaurants_classified['name'], restaurants_classified['class']):
    label = folium.Popup(str(poi) + ' Class ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=marker_colors[cluster],
        fill=True,
        fill_color=marker_colors[cluster],
        fill_opacity=0.7).add_to(map_rest_class)
       
map_rest_class
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_95134983d3934170a31753e26498b7ab%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_95134983d3934170a31753e26498b7ab%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_95134983d3934170a31753e26498b7ab%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_95134983d3934170a31753e26498b7ab%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5074%2C%20-0.1278%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2015%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_9ada59cf8e2c4437b520ee0dc77202f5%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%2 ...

# %% [markdown]
# <h2>Finding the suitable spot</h2>

# %% [markdown]
# In this section we will see what category of restaurants is most trending and desired in center of london. Since our restaurants data represent venues with highest foot-traffic then we will look at the frequency of restaurant category repetition as this are the venues recieving customers.
#
# Then we will look at the number of restaurants in each of the three areas to choose the cluster of hotels with the minimum level of competion, as well as the number of hotels in that cluster to correctly evaluate the opportunity.

# %%
#count number of restaurants in each area
restaurants_count = restaurants_classified['class'].value_counts().rename_axis('class').reset_index(name='counts')
restaurants_count
# Out:
#    class  counts
# 0      1      16
# 1      0       9
# 2      2       2

# %%
#counting number of trending restaurants of each unique category
trending_restaurants = restaurants_classified['categories'].value_counts().rename_axis('categories').reset_index(name='counts')
trending_restaurants
# Out:
#                     categories  counts
# 0             Ramen Restaurant       2
# 1                   Restaurant       2
# 2             Sushi Restaurant       2
# 3           Mexican Restaurant       2
# 4           English Restaurant       2
# 5          Japanese Restaurant       2
# 6            French Restaurant       2
# 7           Seafood Restaurant       1
# 8           Chinese Restaurant       1
# 9          Lebanese Restaurant       1
# 10            Greek Restaurant       1
# 11        Pakistani Restaurant       1
# 12             Thai Restaurant       1
# 13           Indian Restaurant       1
# 14          Spanish Restaurant       1
# 15     North Indian Restaurant       1
# 16   Japanese Curry Restaurant       1
# 17            Asian Restaurant       1
# 18       Portuguese Restaurant       1
# 19  Modern European Restaurant       1

# %%
#keeping the five most frequent categories
trending_restaurants = trending_restaurants.head()

# %%
#show top five categories
trending_restaurants
# Out:
#                     counts
# categories
# Ramen Restaurant         2
# Restaurant               2
# Sushi Restaurant         2
# Mexican Restaurant       2
# English Restaurant       2

# %%
#make "categories" as index for visiualization
trending_restaurants = trending_restaurants.set_index('categories')
trending_restaurants
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-f96fc0ec03b1> in <module>()
#       1 #make "categories" as index for visiualization
# ----> 2 trending_restaurants = trending_restaurants.set_index('categories')
#       3 trending_restaurants
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4553
#    4554         if missing:
# -> 4555             raise KeyError(f"None of {missing} are in the columns")
#    4556
#    4557         if inplace:
#
# KeyError: "None of ['categories'] are in the columns"

# %%
#importing bar charts library
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#plotting the top five restaurant categories
trending_restaurants.plot(kind='bar', figsize=(10, 6), legend=None)

plt.xlabel('Category') # add to x-label to the plot
plt.ylabel('Number of restaurants') # add y-label to the plot
plt.title('Top five trending restaurants categories in London') # add title to the plot

plt.show()

# %%
#counting hotels in each area to evaluate potential
hotels_count = clustered_hotels['cluster_label'].value_counts().rename_axis('cluster').reset_index(name='counts')
hotels_count
# Out:
#    cluster  counts
# 0        1      13
# 1        2       8
# 2        0       6
